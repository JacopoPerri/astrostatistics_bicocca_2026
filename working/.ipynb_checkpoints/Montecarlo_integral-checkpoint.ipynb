# %%
import numpy as np
import random 
import scipy.stats as scist
import matplotlib.pyplot as plt

# %%
# function to integrate: y = x**3 * np.exp(-x**2 / 2*sigma**2)
# np.exp(-x**2 / 2*sigma**2) = gaussian * np.sqrt(2*np.pi*sigma**2) 
# p(x) = gaussian
# f(x) = x**3 * np.sqrt(2*np.pi*sigma**2)

# %%
def f(x, s):
    y = x**3 * np.sqrt(2*np.pi*s**2)
    return y

# %%
def gaussian(x, mu, s):
    return 1/np.sqrt(2*np.pi*s**2) * np.exp(-(x-mu)**2/(2*s**2))

# %%
def perform_integral(sigma, N):
    #N = number of samplings

    initial_xi = np.random.normal(loc=0, scale=sigma, size=N)
    xi = []

    for i in range(N):
        if initial_xi[i] >=0:
            xi.append(initial_xi[i])

    xi = np.array(xi)
    evaluated = f(xi, sigma)

    integral = 1/len(xi) * np.sum(evaluated) * 1/2
    true_res = 2*sigma**4
    error = np.abs(integral-true_res)

    return integral, error

# %%
sigma = 2
N = 20000
results = []
errors = []

for i in range(1000):
    res, err = perform_integral(sigma, N)
    results.append(res)
    errors.append(err)

# %%
#very rough fit of the results

sigma_fit = np.std(results)
mean_fit = np.mean(results)

x_arr = np.linspace(29.5, 34.5, 10000)
y_arr = gaussian(x_arr, mean_fit, sigma_fit) 

fig, ax = plt.subplots()
plt.hist(results, bins=30, density=True)
plt.plot(x_arr, y_arr)

# %%
# does the result converge with the number of samples?
# how does the error reduce?

sampling_number = np.arange(start=50, stop=50000)
results = []
errors = []

for i in range(len(sampling_number)):
    result, error = perform_integral(2, sampling_number[i])
    results.append(result)
    errors.append(error)

# %%
fig, ax = plt.subplots()
ax.errorbar(x=sampling_number, y=results, yerr=np.abs(errors), fmt='o', markersize=1, linestyle='None', alpha=0.5)
ax.set_xlabel('N of samples')
ax.set_ylabel('Value of integral')
# Out:
# Text(0, 0.5, 'Value of integral')

# %%
fig, ax = plt.subplots()
plt.plot(sampling_number, errors, marker='o', markersize=1, linestyle='None', alpha=0.5)
ax.set_xlabel('N of samples')
ax.set_ylabel('Error')
# Out:
# Text(0, 0.5, 'Error')
