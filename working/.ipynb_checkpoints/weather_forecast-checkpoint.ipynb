# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# %%
def extract_weather(today):
    #using the metropolis hastings algorithm
    
    num = uniform.rvs(loc=0, scale=1)
    
    if today == 'c':
        '''
        if today it's cloudy, there is an equal prob of today being either weather
        so I just take the value that has been just extracted to decide the weather
        '''
        extr = round(num) #0 = sun, 1 = cloud

    else:
        '''
        if today it's sunny, there is a higher probability that tomorrow will be sunny again.
        so it will be sunny if 1-num is < 0.9 (very likely) and cloudy if 1-num >= 0.9 (10% of times)
        '''
        if (1-num) < 0.9:
            extr = 0
        else:
            extr = 1

    if extr == 1:
        w = 'c'

    else:
        w = 's'

    return w

# %%
start = 'c'
N = 10000
days_weather = [start]

for i in range(N):
    tomorrow = extract_weather(days_weather[i])
    days_weather.append(tomorrow)

# %%
def cum_days_weat(days):
    cloud = 0
    sun = 0

    cloud_cum = []
    sun_cum = []
    n = len(days)
    
    for i in range(n-1):
        
        if days[i] == 'c':
            cloud += 1
        else:
            sun += 1

        n_days_now = i+1

        frac_cloud = cloud/n_days_now
        frac_sun = sun/n_days_now

        cloud_cum.append(frac_cloud)
        sun_cum.append(frac_sun)

    return cloud_cum, sun_cum

# %%
fig, ax = plt.subplots()

cloud_cum, sun_cum = cum_days_weat(days_weather)
xarr = np.arange(0, N)
plt.plot(xarr, cloud_cum, color='blue', label='fraction of cloudy days')
plt.plot(xarr, sun_cum, color='orange', label='fraction of sunny days')
plt.grid()
plt.xlabel('days')
plt.legend(loc='best')

# %%
plt.hist(cloud_cum, color='blue', alpha=0.5, bins=50)
plt.hist(sun_cum, color='orange', alpha=0.5, bins=50)

print('Prob of clouds: ', np.mean(cloud_cum), '+-', np.std(cloud_cum))
print('Prob of sun: ', np.mean(sun_cum), '+-', np.std(sun_cum))
# Out:
# Prob of clouds:  0.18085808999290487 +- 0.02385202006041473
# Prob of sun:  0.819141910007095 +- 0.02385202006041473
