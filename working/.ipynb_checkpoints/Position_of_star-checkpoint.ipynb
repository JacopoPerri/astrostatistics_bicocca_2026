# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %% [markdown]
# # Part 1

# %%
true_mu = 1
meas_err = 0.2 
N = 20
gen_meas = np.random.normal(loc=true_mu, scale=meas_err, size=N)
x_arr = np.linspace(0, 2, 1000)

fig, ax = plt.subplots()

for i in range(N):
    y_arr = norm.pdf(x_arr, gen_meas[i], meas_err)
    plt.plot(x_arr, y_arr)

# %%
#total likelihood

tot_lik = np.ones(len(x_arr))

for i in range(N):
    tot_lik = tot_lik * norm.pdf(x_arr, gen_meas[i], meas_err)

fig, ax = plt.subplots()
plt.plot(x_arr, tot_lik)

# %%
max_idx = (np.argsort(tot_lik))[-1]
print('Solution: ', x_arr[max_idx])
print('Mean: ', np.mean(gen_meas))
# Out:
# Solution:  1.055055055055055
# Mean:  1.054853105962897

# %% [markdown]
# # Part 2

# %%
# fisher matrix check

log_lik = np.log(tot_lik)
lik_2nd_diff = np.diff(log_lik, n=2)

a = (-lik_2nd_diff / (x_arr[1] - x_arr[0]) ** 2) #np.diff assumes steps = 1, but here the steps are smaller so we normalize
fisher_sigma = 1/np.sqrt(a)[max_idx]

sigma_mu = meas_err / np.sqrt(N)
print(fisher_sigma, '\n', sigma_mu)
# Out:
# 0.04472135954998124
#  0.044721359549995794

# %%
fig, ax = plt.subplots()
plt.plot(x_arr, norm.pdf(x_arr, true_mu, fisher_sigma), color='blue')
plt.plot(x_arr, norm.pdf(x_arr, true_mu, sigma_mu), color='red', linestyle='-.')

# %% [markdown]
# # Part 3

# %%
# Heteroskedastic errors (0.2 mean, 0.05 stdev)

gen_meas = []
gen_errs = np.random.normal(loc=0.2, scale=0.05, size=N)

for i in range(N):
    val = np.random.normal(loc=true_mu, scale=gen_errs[i])
    gen_meas.append(val)

gen_meas = np.array(gen_meas)

x_arr = np.linspace(0, 2, 1000)

fig, ax = plt.subplots()

for j in range(N):
    y_arr = norm.pdf(x_arr, gen_meas[j], gen_errs[j])
    plt.plot(x_arr, y_arr)

# %%
tot_lik = np.ones(len(x_arr))

for i in range(N):
    tot_lik = tot_lik * norm.pdf(x_arr, gen_meas[i], gen_errs[i])

fig, ax = plt.subplots()
plt.plot(x_arr, tot_lik)

# %%
max_idx = (np.argsort(tot_lik))[-1]
print('Solution: ', x_arr[max_idx])
print('Mean: ', np.average(gen_meas, weights=gen_errs))
print('Median: ', np.median(gen_meas))
# Out:
# Solution:  0.960960960960961
# Mean:  0.9558861252240947
# Median:  0.9397764133198704
