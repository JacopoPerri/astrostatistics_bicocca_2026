# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.naive_bayes import GaussianNB

# %%
dataset = pd.read_csv('galaxyquasar.csv')

# %%
dataset
# Out:
#               u         g         r         i         z   class        z1  \
# 0      18.97213  18.53676  18.58280  18.34936  18.29215     QSO  0.522819
# 1      19.24592  17.47646  16.47817  16.04472  15.68851  GALAXY  0.122846
# 2      19.43536  17.70268  16.91565  16.58327  16.39128  GALAXY  0.000000
# 3      19.31626  18.18312  17.39591  16.94549  16.65395  GALAXY  0.147435
# 4      19.28828  19.11188  18.88937  18.80013  18.49183     QSO  2.011455
# ...         ...       ...       ...       ...       ...     ...       ...
# 49995  19.37295  18.12382  17.39886  16.98503  16.70585  GALAXY  0.113016
# 49996  18.52021  16.88262  16.03280  15.56884  15.22454  GALAXY  0.085063
# 49997  18.62718  17.30876  16.87371  16.62399  16.42296  GALAXY  0.054429
# 49998  19.55140  18.27711  17.62101  17.21947  17.03347  GALAXY  0.112571
# 49999  18.80772  17.75751  17.40500  17.21650  17.12295  GALAXY  0.043652
#
#            zerr
# 0      0.000155
# 1      0.000028
# 2      0.000000
# ...

# %%
ug = dataset['u'] - dataset['g']
gr = dataset['g'] - dataset['r']
ri = dataset['r'] - dataset['i']
iz = dataset['i'] - dataset['z']

# %%
classes = dataset['class']

# %%
dataset['class'] = dataset['class'].map({'QSO': 1, 'GALAXY': 0}).astype(int)

# %%
# ug = x, gr = y
X1 = np.array(ug)
X1 = np.array(X1[:, np.newaxis])
y1 = np.array(gr)

# %%
clf = GaussianNB()
clf.fit(X1, y1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 clf = GaussianNB()
# ----> 2 clf.fit(X1, y1)
#
# File ~\anaconda3\envs\New_env_for_fun\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\New_env_for_fun\Lib\site-packages\sklearn\naive_bayes.py:279, in GaussianNB.fit(self, X, y, sample_weight)
#     277 y = validate_data(self, y=y)
#     278 xp_y, _ = get_namespace(y)
# --> 279 return self._partial_fit(
# ...
