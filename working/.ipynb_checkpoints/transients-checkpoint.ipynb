# %%
import numpy as np
import emcee 
import matplotlib.pyplot as plt
from scipy.stats import uniform, norm
import corner

# %%
transient = np.load('transient.npy')
time = transient[:, 0]
flux = transient[:, 1]
errs = transient[:, 2]

# %%
def mymodel(params, t):
    b, t0, A, alpha = params
    y = np.zeros(len(t))
    cond = t<t0
    y[cond] += b
    y[~cond] += b+A*np.exp(-alpha*(t[~cond]-t0))
    return y

# %%
test_params = (10, 50, 5, 0.1)
xarr = np.linspace(0, 100, 10000)
fig, ax = plt.subplots()
plt.errorbar(time, flux, yerr=errs, fmt='o')
plt.plot(xarr, mymodel(test_params, xarr))

# %%
def log_lik(params, datatable):
    
    times, fluxes, sigma_y = datatable.T
    y_fit = mymodel(params, times)
    
    return -0.5 * np.sum((fluxes-y_fit)**2 / sigma_y**2 ) 

def log_prior(params):
    b, t0, A, alpha = params
    zero = 0
    bmax = 50
    t0max = 100
    alphamin = np.exp(-5)
    alphamax = np.exp(5)

    if zero < b < bmax and zero < A < bmax and zero < t0 < t0max and alphamin < alpha < alphamax:
        return 0.0 - np.log(alpha)

    else:
        return -np.inf

def log_post(params, datatable):
    return log_lik(params, datatable) + log_prior(params)

# %% [markdown]
# # Using Emcee

# %%
nsteps = 50000
nparams = 4
nwalkers = 30
starting_guesses = test_params + 0.1*np.random.randn(nwalkers, nparams)

# %%
sampler = emcee.EnsembleSampler(nwalkers, nparams, log_post, args=[transient])
sampler.run_mcmc(starting_guesses, nsteps);
# Out:
# C:\Users\perri\anaconda3\envs\New_env_for_fun\Lib\site-packages\emcee\moves\red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# [58.59401672 75.85355687 75.35159326 63.69381155]

# %%
# first open the chain to see what the burn time roughly is

chain = sampler.get_chain(flat=True)
b_chain = chain[:, 0]
t0_chain = chain[:, 1]
A_chain = chain[:, 2]
alpha_chain = chain[:, 3]

# %%
plt.plot(b_chain)

# %%
plt.plot(t0_chain)

# %%
plt.plot(A_chain)

# %%
plt.plot(alpha_chain)

# %%
# burn and thin chains

burn = 3000
autocorr = int(max(tau)) 
lbl = ['b', 't0', 'A', 'alpha']
chain = sampler.get_chain(discard=burn, thin=autocorr, flat=True)
figure = corner.corner(chain, labels=lbl, levels=[0.68,0.95])

# %%
# 100 random models from our results

choices = []

for i in range(4):
    this_chain = chain[:,  i]
    choice = np.random.choice(this_chain, size=100)
    choices.append(choice)

choices = np.array(choices)
print(choices.shape)
# Out:
# (4, 100)

# %%
for i in range(100):
    params = choices[:, i]
    plt.plot(xarr, mymodel(params, xarr), alpha=0.3, color='black')

plt.errorbar(time, flux, yerr=errs, fmt='o')
plt.xlabel('t')
plt.ylabel('flux')
plt.grid()

# %%
# median and 90% credible interval of parameters

medians = []
for i in range(4):
    medians.append(np.median(chain[:, i]))

uppers = []
lowers = []

for i in range(4):
    uppers.append(np.percentile(chain[:, i], 95))
    lowers.append(np.percentile(chain[:, i], 5))

# %%
for i in range(4):
    print(lbl[i], '=', medians[i], '+', uppers[i]-medians[i], '-', medians[i]-lowers[i])
# Out:
# b = 10.29741283080066 + 0.19710608527910445 - 0.20086970128397397
# t0 = 49.08585940256326 + 2.7507237168294907 - 2.019163523551825
# A = 5.403196577613587 + 3.406712872572756 - 1.7904764053016011
# alpha = 0.12244635218294952 + 0.054310860911377545 - 0.03684577466419506

# %%
fig, ax = plt.subplots()
plt.plot(xarr, mymodel(medians, xarr))
plt.errorbar(time, flux, yerr=errs, fmt='o')
plt.title('Best model')
plt.grid()
plt.xlabel('t')
plt.ylabel('flux')
# Out:
# Text(0, 0.5, 'flux')
