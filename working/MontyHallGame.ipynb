# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def host(arr):
    #the host always chooses a goat door
    goats = []
    for i in range(len(arr)):
        if arr[i] == 0:
            goats.append(i) #annotate where the goats are
    choice = goats[random.randint(0, len(goats))-1] #choose a goat door
    return choice

# %%
def switcher(arr, firstchoice):
    #always changes choice; input arr should be "available doors"
    choice = 0
    for i in range(len(arr)):
        if arr[i] != firstchoice:
            choice = i
    return choice

# %%
def conservative(arr, firstchoice):
    #never changes
    choice = 0
    for i in range(len(arr)):
        if arr[i] == firstchoice:
            choice = i
    return choice

# %%
def newcomer(arr, firstchoice):
    #random choice
    choice = arr[random.randint(0, len(arr)-1)]
    return choice

# %%
doors = np.array([0, 0, 1]) #0 = goat, 1 = car
N_iterations = 10000

switcher_wins = 0
conservative_wins = 0
newcomer_wins = 0

j = 0

while j <= N_iterations:
    np.random.shuffle(doors)

    first_choice = random.randint(0, 2) #1st choice of the player
    host_choice = host(doors)

    available_doors = []
    for i in range(len(doors)):
        if i != host_choice:
            available_doors.append(i)

    switcher_choice = switcher(available_doors, first_choice)
    conservative_choice = conservative(available_doors, first_choice)
    newcomer_choice = newcomer(available_doors, first_choice)

    if switcher_choice == 1:
        switcher_wins +=1

    if conservative_choice == 1:
        conservative_wins +=1

    if newcomer_choice == 1:
        newcomer_wins +=1

    j += 1


print('Switcher wins: ', switcher_wins)
print('Conservative wins: ', conservative_wins)
print('Newcomer wins: ', newcomer_wins)
# Out:
# Switcher wins:  6604
# Conservative wins:  3397
# Newcomer wins:  3307
